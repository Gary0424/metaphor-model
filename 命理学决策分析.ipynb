# %% [markdown]
# # ☯ 命理学结构化决策分析
#
# 从中国传统命理学（八字、五行、十神、大运）中提取结构化分析思维，去掉玄学宣称，改造成现代决策分析工具。
#
# ## 核心思想
#
# | 命理学概念 | 现代决策对应 |
# |---|---|
# | 八字（年月日时）| 四维情境编码（环境/局势/自身/目标）|
# | 五行（金木水火土）| 五种抽象力量（创造/表现/稳定/决断/流动）|
# | 生克关系 | 资源间的促进/制约 |
# | 十神 | 利益相关者角色 |
# | 大运流年 | 时间阶段推演 |

# %%
# 安装依赖
# !pip install fastapi uvicorn pydantic -q

# %%
# 启动 Web 应用
# AI Studio Notebook 环境下会自动暴露端口
# 点击 "Web Preview" 或访问暴露的 URL 即可使用
import subprocess, sys
subprocess.Popen([sys.executable, 'app.py'])
print('✅ 应用已启动！点击右侧 "Web Preview" 查看，或访问暴露的 8088 端口')

# %% [markdown]
# ## 命令行用法
#
# 也可以不启动 Web，直接在 Notebook 里用 Python 分析：
#
# ```python
# from app import *
#
# sit = Situation(
#     question="要不要跳槽？",
#     dimensions=[
#         Dimension(Pillar.YEAR, Element.WATER, 7, "经济环境不确定"),
#         Dimension(Pillar.MONTH, Element.METAL, 8, "大厂天花板明显"),
#         Dimension(Pillar.DAY, Element.WOOD, 7, "有创造力想做事"),
#         Dimension(Pillar.HOUR, Element.FIRE, 6, "想要更大影响力"),
#     ],
#     stakeholders=[
#         Stakeholder("大厂体系", Role.AUTHORITY, Element.METAL, 8, "制度约束"),
#         Stakeholder("创业CEO", Role.RESOURCE, Element.WOOD, 7, "给机会"),
#     ],
# )
#
# az = MetaphorAnalyzer(sit)
# report, data = az.full_report()
# print(report)
# ```
